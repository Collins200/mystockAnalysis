# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url='https://live.mystocks.co.ke/price_list/20210719'
soup=BeautifulSoup(requests.get(url).content,'html.parser')

print(soup)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="en">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <title>Price list and trading summary for Monday, July 19, 2021</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Price list and trading summary for Monday, July 19, 2021" name="description"/>
# <meta content="Live Quotes, Real-time, myStocks, Portfolio, Portfolio Manager, Portfolio Valuation, Market Analysis, Nairobi Securities Exchange, Stocks, Mobile" name="keywords"/>
# <meta content="720111951" property="fb:admins"/>
# <meta content="132822503413695" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="myStocks" property="og:site_name"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="//cdn-ke.mystocks.co.ke/res/mystocks_core_$20200909111206.css" rel="stylesheet" type="text/css"/>
# ...

# %%
title=soup.find('title').get_text()
title
# soup.title.get_text()
# Out:
# 'Price list and trading summary for Monday, July 19, 2021'

# %%
table=soup.find('table',class_='tblHoverHi')
coloumns=soup.find('tr',class_='row')
coloumns
# Out:
# <tr class="row">
# <th colspan="2">
# <th class="c bl bt bb" colspan="2">LAST 12 MONTHS
# <th class="c bl bt bb" colspan="3">DAY'S TRADING
# <th class="bl bb">
# <th colspan="4">
# <th class="b2 r" rowspan="2" title="VWAP Price adjusted for bonus issues and share splits">Adjusted Price
# <tr class="row">
# <th class="b2">CODE
# <th class="b2">NAME
# <th class="b2 r bl">Low
# <th class="b2 r bl">High
# <th class="b2 r bl">Low
# <th class="b2 r bl">High
# <th class="b2 r bl" title="Volume-weighted Average Price (VWAP)">Price
# <th class="b2 r bl br" title="Previous VWAP">Previous
# <th class="b2 c" colspan="3">Change
# <th class="b2 r">Volume<tr class="row">
# <td class="b2" colspan="13"><h3>Agricultural</h3><tr class="row">
# <td class="nm">EGAD<td class="nm"><a href="/stock=EGAD">Eaagads Ltd</a>
# ...

# %%
column=["CODE","NAME","LAST12MONTHS_low","LAST12MONTHS_high","Day'S_Trade_low",
        "Day's_Trade_high","price","previous_price",
        "price_change","percent_change","indicator_change","volume","adjusted_price"]
data={}
import json
for tr in soup.find_all('tr',class_='row')[2:]:
    if tr.find_all('td')==tr.find_all('h3'):
        pass
    else:
        tds=tr.find_all('td')
#         h3=tr.find_all('h3')
#         print(h3[0].text)
        print(tds[0].text)
#         print(json.dumps(tds[0].text,indent=2))
# Out:
# Agricultural
# EGADEaagads Ltd
# 9.0015.0011.0011.8011.0011.85(0.85)7.17%▼10,100-
# KUKZKakuzi Plc
# 351.00405.00372.75372.75372.75372.75-- --
# KAPCKapchorua Tea Kenya Plc
# 68.50101.0098.0098.0098.0098.00-- 100-
# LIMTLimuru Tea Plc
# 290.00400.00290.00290.00290.00295.00(5.00)1.69%▼300-
# SASNSasini Plc
# 16.0020.0019.0019.9519.2019.000.201.05%▲1,300-
# WTKWilliamson Tea Kenya Plc
# 119.00154.75152.25152.25152.25152.25-- --
# Automobiles and Accessories
# CGENCar and General (K) Ltd
# 20.0031.0031.0031.0031.0030.001.003.33%▲400-
# Banking
# ABSAABSA Bank Kenya Plc
# 8.5010.8010.0010.1010.0010.00-- 710,000-
# BKGBK Group Plc
# 12.1528.0028.0028.0028.0028.00-- --
# COOPCo-operative Bank of Kenya Ltd
# 10.2014.0513.1013.7513.4513.50(0.05)0.37%▼731,900-
# DTKDiamond Trust Bank Kenya Ltd
# 57.5078.5066.0069.0069.0066.252.754.15%▲3,283,400-
# EQTYEquity Group Holdings Plc
# 28.0049.4548.2548.6048.5548.55-- 1,476,900-
# HFCKHF Group Ltd
# 2.865.483.683.803.733.700.030.81%▲19,200-
# ...

# %%
 print(json.dumps(tds[0].text,indent=2))
# Out:
# "^ZKEQTUZamara Kenya Equity Index (USD)\n1,201.291,740.411,736.321,736.321,736.321,734.451.870.11%\u25b2--\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
